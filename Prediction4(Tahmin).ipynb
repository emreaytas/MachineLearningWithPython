# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LinearRegression
from IPython.display import Image # resim import etmek için kullanırız.    Image(filename = "") ile ise resmi import ederiz.
import pandas as pd
import numpy as np
import sklearn as skl
import matplotlib.pyplot as plt
import seaborn as sbn 
import tensorflow as tf

# %% [markdown]
# ## DESTEK VEKTÖR(SUPPORT VECTOR)

# %%
Image(filename="FOTO14.png") # eskiden sınıflandırma için kullanılırmış maksimum aralığı bulmak için kullanılırmış.
